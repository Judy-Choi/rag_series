# %% [markdown]
# ## Load File

# %%
file_name = "../data/[일반보험]_KB개인상해보험_보험약관.pdf"

# %% [markdown]
# ## PyPDF

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(file_name)
docs = loader.load()

docs
# Out:
# [Document(metadata={'source': '../data/[일반보험]_KB개인상해보험_보험약관.pdf', 'page': 0}, page_content='KB개인상해보험'),
# ...

# %% [markdown]
# ### Text

# %%
# Get only 10p
print(docs[9].page_content)

# Original Source
# result_text = []

# for page in docs:
#     text = page.page_content
#     result_text.append(text)

# print(result_text[9])
# Out:
# 보험용어 해설
# 보험용어 용어 해설
# 보험약관보험계약에 관하여 보험계약자와 보험회사 상호간에 이행하여야 할 권리
# 와 의무를 규정한 것
# 보험증권보험계약의 성립과 그 내용을 증명하기 위하여 보험회사가 보험계약자에
# 게 교부하는 증서
# 보험계약자 보험회사와 계약을 체결하고 보험료 납입의무를 지는 사람
# 피보험자 보험사고 발생의 대상이 되는 사람
# 보험수익자 보험사고 발생시 보험금 청구권을 갖는 사람
# 보험료 보험계약자가 보험계약에 의거하여 보험회사에게 지급하여야하는 요금
# 보험목적 보험사고의 발생의 객체가 되는 경제상의 재화
# 보험가액재산보험에 있어 피보험 이익을 금전으로 평가한 금액으로 보험의 목적
# 에 발생할 수 있는 최대 손해액을 말합니다 .(회사가 실제 지급하는 보험
# 금은 보험가액을 초과할 수 없습니다 )
# 보험가입금액보험사고 발생시 보험회사가 지급하여야 할 보험금의 기준이 되는 금액
# 으로 보험증권에 기재된 금액
# 보험금◦ 신체손해 ·비용손해 보장 : 피보험자의 사망, 장해, 입원 등 보험금 지
# 급사유가 발생하였을 때 보험회사가 보험수익자에게 지급하는 금액
# ◦ 재물손해 ·배상책임 보장 : 피보험자의 재물손해 , 배상책임손해 등 보험
# 금 지급사유가 발생하였을 때 보험회사가 피보험자에게 지급하는 금액
# 보험기간 계약에 따라 보장을 받는 기간으로 보험증권에 기재된 기간
# 보장개시일 보험회사의 보험금 지급의무가 시작되는 날
# 보험년도보험계약일로부터 매1년 단위의 연도(당해연도 보험계약 해당일부터 다
# 음연도 보험계약 해당일 전일까지의 기간)를 말함
# 영업일회사가 영업점에서 정상적으로 영업하는 날을 말하며 , “토요일 ”, “관공
# 서의 공휴일에 관한 규정에 따른 공휴일 ” 및 “근로자의 날”을 제외한 날
# 을 의미합니다 .

# %% [markdown]
# ## Fitz

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader(file_name)
docs = loader.load()

docs
# Out:
# [Document(metadata={'source': '../data/[일반보험]_KB개인상해보험_보험약관.pdf', 'file_path': '../data/[일반보험]_KB개인상해보험_보험약관.pdf', 'page': 0, 'total_pages': 203, 'format': 'PDF 1.4', 'title': '', 'author': 'kbins', 'subject': '', 'keywords': '', 'creator': 'Hwp 2018 10.0.0.8223', 'producer': 'Hancom PDF 1.3.0.534', 'creationDate': "D:20240402114023+09'00'", 'modDate': "D:20240402114023+09'00'", 'trapped': ''}, page_content='KB개인상해보험\n'),
# ...

# %% [markdown]
# ### Text

# %% [markdown]
# Loader 를 사용하여 문서를 로드한 경우

# %%
# Get only 10p
print(docs[9].page_content)

# Original Source
# result_text = []

# for page in docs:
#     text = page.page_content
#     result_text.append(text)

# print(result_text[9])
# Out:
# 보험용어 해설
# 보험용어
# 용어 해설
# 보험약관
# 보험계약에 관하여 보험계약자와 보험회사 상호간에 이행하여야 할 권리
# 와 의무를 규정한 것
# 보험증권
# 보험계약의 성립과 그 내용을 증명하기 위하여 보험회사가 보험계약자에
# 게 교부하는 증서
# 보험계약자
# 보험회사와 계약을 체결하고 보험료 납입의무를 지는 사람
# 피보험자
# 보험사고 발생의 대상이 되는 사람
# 보험수익자
# 보험사고 발생시 보험금 청구권을 갖는 사람
# 보험료
# 보험계약자가 보험계약에 의거하여 보험회사에게 지급하여야하는 요금
# 보험목적
# 보험사고의 발생의 객체가 되는 경제상의 재화
# 보험가액
# 재산보험에 있어 피보험 이익을 금전으로 평가한 금액으로 보험의 목적
# 에 발생할 수 있는 최대 손해액을 말합니다.(회사가 실제 지급하는 보험
# 금은 보험가액을 초과할 수 없습니다)
# 보험가입금액
# 보험사고 발생시 보험회사가 지급하여야 할 보험금의 기준이 되는 금액
# 으로 보험증권에 기재된 금액
# 보험금
# ◦ 신체손해·비용손해 보장 : 피보험자의 사망, 장해, 입원 등 보험금 지
# 급사유가 발생하였을 때 보험회사가 보험수익자에게 지급하는 금액
# ◦ 재물손해·배상책임 보장 : 피보험자의 재물손해, 배상책임손해 등 보험
# 금 지급사유가 발생하였을 때 보험회사가 피보험자에게 지급하는 금액
# 보험기간
# 계약에 따라 보장을 받는 기간으로 보험증권에 기재된 기간
# 보장개시일
# 보험회사의 보험금 지급의무가 시작되는 날
# 보험년도
# 보험계약일로부터 매1년 단위의 연도(당해연도 보험계약 해당일부터 다
# 음연도 보험계약 해당일 전일까지의 기간)를 말함
# 영업일
# 회사가 영업점에서 정상적으로 영업하는 날을 말하며, “토요일”, “관공
# 서의 공휴일에 관한 규정에 따른 공휴일” 및 “근로자의 날”을 제외한 날
# 을 의미합니다.

# %% [markdown]
# fitz 의 get_text() 를 이용할 경우

# %%
import fitz

result_text = []

# fitz.open 을 사용할 수도 있고
docs = fitz.open(file_name)

# Get only 10p
print(docs[9].get_text())

# for page in docs:
#     text = page.get_text()
#     result_text.append(text)


# with fitz.open 을 사용할 수도 있음.
# with fitz.open(file_name) as pdf_pages:
#     for page in pdf_pages:
#         text = page.get_text()
#         result_text.append(text)

# Get only 10p
# print(result_text[9])

# 명시적으로 파일 닫기
docs.close()
# Out:
# 보험용어 해설
# 보험용어
# 용어 해설
# 보험약관
# 보험계약에 관하여 보험계약자와 보험회사 상호간에 이행하여야 할 권리
# 와 의무를 규정한 것
# 보험증권
# 보험계약의 성립과 그 내용을 증명하기 위하여 보험회사가 보험계약자에
# 게 교부하는 증서
# 보험계약자
# 보험회사와 계약을 체결하고 보험료 납입의무를 지는 사람
# 피보험자
# 보험사고 발생의 대상이 되는 사람
# 보험수익자
# 보험사고 발생시 보험금 청구권을 갖는 사람
# 보험료
# 보험계약자가 보험계약에 의거하여 보험회사에게 지급하여야하는 요금
# 보험목적
# 보험사고의 발생의 객체가 되는 경제상의 재화
# 보험가액
# 재산보험에 있어 피보험 이익을 금전으로 평가한 금액으로 보험의 목적
# 에 발생할 수 있는 최대 손해액을 말합니다.(회사가 실제 지급하는 보험
# 금은 보험가액을 초과할 수 없습니다)
# 보험가입금액
# 보험사고 발생시 보험회사가 지급하여야 할 보험금의 기준이 되는 금액
# 으로 보험증권에 기재된 금액
# 보험금
# ◦ 신체손해·비용손해 보장 : 피보험자의 사망, 장해, 입원 등 보험금 지
# 급사유가 발생하였을 때 보험회사가 보험수익자에게 지급하는 금액
# ◦ 재물손해·배상책임 보장 : 피보험자의 재물손해, 배상책임손해 등 보험
# 금 지급사유가 발생하였을 때 보험회사가 피보험자에게 지급하는 금액
# 보험기간
# 계약에 따라 보장을 받는 기간으로 보험증권에 기재된 기간
# 보장개시일
# 보험회사의 보험금 지급의무가 시작되는 날
# 보험년도
# 보험계약일로부터 매1년 단위의 연도(당해연도 보험계약 해당일부터 다
# 음연도 보험계약 해당일 전일까지의 기간)를 말함
# 영업일
# 회사가 영업점에서 정상적으로 영업하는 날을 말하며, “토요일”, “관공
# 서의 공휴일에 관한 규정에 따른 공휴일” 및 “근로자의 날”을 제외한 날
# 을 의미합니다.

# %% [markdown]
# ### Table

# %%
# import package PyMuPDF
import fitz
import pandas as pd

# Open some document, for example a PDF (could also be EPUB, XPS, etc.)
docs = fitz.open(file_name)

# Load 10p & Look for tables on this page and display the table count
tabs = docs[9].find_tables()

# Select the first table
table = tabs[0]
    
# 표가 추출되었는지 확인
if table:
    # pandas DataFrame으로 변환
    df = table.to_pandas()
    # DataFrame을 Markdown 형식으로 변환
    markdown_table = df.to_markdown(index=False)  # 인덱스를 제외하려면 index=False

    print(markdown_table)

# 명시적으로 파일 닫기
docs.close()
# Out:
# | 보험용어     | 용어 해설                                                            |
# |:-------------|:---------------------------------------------------------------------|
# | 보험약관     | 보험계약에 관하여 보험계약자와 보험회사 상호간에 이행하여야 할 권리  |
# |              | 와 의무를 규정한 것                                                  |
# | 보험증권     | 보험계약의 성립과 그 내용을 증명하기 위하여 보험회사가 보험계약자에  |
# |              | 게 교부하는 증서                                                     |
# | 보험계약자   | 보험회사와 계약을 체결하고 보험료 납입의무를 지는 사람               |
# | 피보험자     | 보험사고 발생의 대상이 되는 사람                                     |
# | 보험수익자   | 보험사고 발생시 보험금 청구권을 갖는 사람                            |
# | 보험료       | 보험계약자가 보험계약에 의거하여 보험회사에게 지급하여야하는 요금    |
# | 보험목적     | 보험사고의 발생의 객체가 되는 경제상의 재화                          |
# | 보험가액     | 재산보험에 있어 피보험 이익을 금전으로 평가한 금액으로 보험의 목적   |
# |              | 에 발생할 수 있는 최대 손해액을 말합니다.(회사가 실제 지급하는 보험  |
# |              | 금은 보험가액을 초과할 수 없습니다)                                  |
# ...

# %% [markdown]
# ### Image

# %% [markdown]
# 공식문서 코드

# %%
import fitz  # PyMuPDF
import io
import os
from PIL import Image

# 'fitz_image' 폴더가 없으면 새로 생성합니다.
output_folder = "fitz_image"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)


# Open the file
pdf_file = fitz.open(file_name)

# Iterate over PDF pages
for page_index in range(len(pdf_file)):
    # Get the page itself
    page = pdf_file[page_index]

    # Get the image list for the page
    image_list = page.get_images(full=True)

    # Printing the number of images found on this page
    if image_list:
        print(f"[+] Found a total of {len(image_list)} images in page {page_index + 1}")
    # else:
    #     print("[!] No images found on page", page_index + 1)

    # Extract images from the page
    for image_index, img in enumerate(image_list, start=1):
        xref = img[0]
        base_image = pdf_file.extract_image(xref)
        image_bytes = base_image["image"]
        image_ext = base_image["ext"]

        # Save the image to a file
        image_filename = f"{output_folder}/page_{page_index + 1}_image_{image_index}.{image_ext}"
        with open(image_filename, "wb") as img_file:
            img_file.write(image_bytes)

# Close the PDF document
pdf_file.close()
# Out:
# [+] Found a total of 4 images in page 6
# [+] Found a total of 2 images in page 37
# [+] Found a total of 2 images in page 42
# [+] Found a total of 3 images in page 43

# %% [markdown]
# ChatGPT (함수형)

# %%
import os
import io

def extract_images_from_pdf(file_name, output_folder):
    # PDF 파일 열기
    docs = fitz.open(file_name)

    for page_num in range(docs.page_count):
        page = docs.load_page(page_num)
        
        # 페이지에서 이미지 객체 가져오기
        img_list = page.get_images(full=True)
        
        for img_index, img in enumerate(img_list):
            xref = img[0]
            base_image = docs.extract_image(xref)
            image_bytes = base_image["image"]
            image_ext = base_image["ext"]
            
            # 이미지 바이트를 이미지 객체로 변환
            image = Image.open(io.BytesIO(image_bytes))
            
            # 이미지 저장
            image_filename = f"{output_folder}/page_{page_num+1}_img_{img_index+1}.png"
            image.save(image_filename)
            print(f"Image saved: {image_filename}")
    
    # 명시적으로 파일 닫기
    docs.close()

# 사용 예시
output_folder = "fitz_images_png"  # 이미지가 저장될 폴더
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
extract_images_from_pdf(file_name, output_folder)
# Out:
# Image saved: fitz_images_png/page_6_img_1.png
# Image saved: fitz_images_png/page_6_img_2.png
# Image saved: fitz_images_png/page_6_img_3.png
# Image saved: fitz_images_png/page_6_img_4.png
# Image saved: fitz_images_png/page_37_img_1.png
# Image saved: fitz_images_png/page_37_img_2.png
# Image saved: fitz_images_png/page_42_img_1.png
# Image saved: fitz_images_png/page_42_img_2.png
# Image saved: fitz_images_png/page_43_img_1.png
# Image saved: fitz_images_png/page_43_img_2.png
# Image saved: fitz_images_png/page_43_img_3.png

# %% [markdown]
# ## PDFPlumber

# %%
from langchain.document_loaders import PDFPlumberLoader

loader = PDFPlumberLoader(file_name)
docs = loader.load()

docs
# Out:
# [Document(metadata={'source': '../data/[일반보험]_KB개인상해보험_보험약관.pdf', 'file_path': '../data/[일반보험]_KB개인상해보험_보험약관.pdf', 'page': 0, 'total_pages': 203, 'Author': 'kbins', 'Creator': 'Hwp 2018 10.0.0.8223', 'Producer': 'Hancom PDF 1.3.0.534', 'CreationDate': "D:20240402114023+09'00'", 'ModDate': "D:20240402114023+09'00'", 'PDFVersion': '1.4'}, page_content='KB개인상해보험\n'),
# ...

# %% [markdown]
# ### Text

# %% [markdown]
# Loader 를 사용하여 문서를 로드한 경우

# %%
# Get only 10p
print(docs[9].page_content)

# Original Source
# result_text = []

# for page in docs:
#     text = page.page_content
#     result_text.append(text)

# print(result_text[9])
# Out:
# 보험용어 해설
# 보험용어 용어 해설
# 보험계약에 관하여 보험계약자와 보험회사 상호간에 이행하여야 할 권리
# 보험약관
# 와 의무를 규정한 것
# 보험계약의 성립과 그 내용을 증명하기 위하여 보험회사가 보험계약자에
# 보험증권
# 게 교부하는 증서
# 보험계약자 보험회사와 계약을 체결하고 보험료 납입의무를 지는 사람
# 피보험자 보험사고 발생의 대상이 되는 사람
# 보험수익자 보험사고 발생시 보험금 청구권을 갖는 사람
# 보험료 보험계약자가 보험계약에 의거하여 보험회사에게 지급하여야하는 요금
# 보험목적 보험사고의 발생의 객체가 되는 경제상의 재화
# 재산보험에 있어 피보험 이익을 금전으로 평가한 금액으로 보험의 목적
# 보험가액 에 발생할 수 있는 최대 손해액을 말합니다.(회사가 실제 지급하는 보험
# 금은 보험가액을 초과할 수 없습니다)
# 보험사고 발생시 보험회사가 지급하여야 할 보험금의 기준이 되는 금액
# 보험가입금액
# 으로 보험증권에 기재된 금액
# ◦ 신체손해·비용손해 보장 : 피보험자의 사망, 장해, 입원 등 보험금 지
# 급사유가 발생하였을 때 보험회사가 보험수익자에게 지급하는 금액
# 보험금
# ◦ 재물손해·배상책임 보장 : 피보험자의 재물손해, 배상책임손해 등 보험
# 금 지급사유가 발생하였을 때 보험회사가 피보험자에게 지급하는 금액
# 보험기간 계약에 따라 보장을 받는 기간으로 보험증권에 기재된 기간
# 보장개시일 보험회사의 보험금 지급의무가 시작되는 날
# 보험계약일로부터 매1년 단위의 연도(당해연도 보험계약 해당일부터 다
# 보험년도
# 음연도 보험계약 해당일 전일까지의 기간)를 말함
# 회사가 영업점에서 정상적으로 영업하는 날을 말하며, “토요일”, “관공
# 영업일 서의 공휴일에 관한 규정에 따른 공휴일” 및 “근로자의 날”을 제외한 날
# 을 의미합니다.

# %% [markdown]
# 공식문서의 라이브러리를 이용하는 경우

# %%
import pdfplumber

with pdfplumber.open(file_name) as pdf:
    # Get only 10p
    print(pdf.pages[9].extract_text())

# Original Source
# result_text = []

# with pdfplumber.open(pdf_path) as pdf:
#     # 각 페이지에서 텍스트 추출
#     for page in pdf.pages:
#         text = page.extract_text()  # 페이지에서 텍스트 추출
#         result_text.append(text)
# print(result_text[9])
# Out:
# 보험용어 해설
# 보험용어 용어 해설
# 보험계약에 관하여 보험계약자와 보험회사 상호간에 이행하여야 할 권리
# 보험약관
# 와 의무를 규정한 것
# 보험계약의 성립과 그 내용을 증명하기 위하여 보험회사가 보험계약자에
# 보험증권
# 게 교부하는 증서
# 보험계약자 보험회사와 계약을 체결하고 보험료 납입의무를 지는 사람
# 피보험자 보험사고 발생의 대상이 되는 사람
# 보험수익자 보험사고 발생시 보험금 청구권을 갖는 사람
# 보험료 보험계약자가 보험계약에 의거하여 보험회사에게 지급하여야하는 요금
# 보험목적 보험사고의 발생의 객체가 되는 경제상의 재화
# 재산보험에 있어 피보험 이익을 금전으로 평가한 금액으로 보험의 목적
# 보험가액 에 발생할 수 있는 최대 손해액을 말합니다.(회사가 실제 지급하는 보험
# 금은 보험가액을 초과할 수 없습니다)
# 보험사고 발생시 보험회사가 지급하여야 할 보험금의 기준이 되는 금액
# 보험가입금액
# 으로 보험증권에 기재된 금액
# ◦ 신체손해·비용손해 보장 : 피보험자의 사망, 장해, 입원 등 보험금 지
# 급사유가 발생하였을 때 보험회사가 보험수익자에게 지급하는 금액
# 보험금
# ◦ 재물손해·배상책임 보장 : 피보험자의 재물손해, 배상책임손해 등 보험
# 금 지급사유가 발생하였을 때 보험회사가 피보험자에게 지급하는 금액
# 보험기간 계약에 따라 보장을 받는 기간으로 보험증권에 기재된 기간
# 보장개시일 보험회사의 보험금 지급의무가 시작되는 날
# 보험계약일로부터 매1년 단위의 연도(당해연도 보험계약 해당일부터 다
# 보험년도
# 음연도 보험계약 해당일 전일까지의 기간)를 말함
# 회사가 영업점에서 정상적으로 영업하는 날을 말하며, “토요일”, “관공
# 영업일 서의 공휴일에 관한 규정에 따른 공휴일” 및 “근로자의 날”을 제외한 날
# 을 의미합니다.

# %% [markdown]
# ### Table

# %%
import pdfplumber
import pandas as pd


# PDF 파일 열기
with pdfplumber.open(file_name) as pdf:
    # Load 10p & Look for tables on this page and display the table count
    table = pdf.pages[9].extract_table()

    # 표가 추출되었는지 확인
    if table:
        # pandas DataFrame으로 변환
        df = pd.DataFrame(table[1:], columns=table[0])  # 첫 번째 행은 컬럼명
        # DataFrame을 Markdown 형식으로 변환
        markdown_table = df.to_markdown(index=False)  # 인덱스를 제외하려면 index=False

        print(markdown_table)
# Out:
# | 보험용어     | 용어 해설                                                            |
# |:-------------|:---------------------------------------------------------------------|
# | 보험약관     | 보험계약에 관하여 보험계약자와 보험회사 상호간에 이행하여야 할 권리  |
# |              | 와 의무를 규정한 것                                                  |
# | 보험증권     | 보험계약의 성립과 그 내용을 증명하기 위하여 보험회사가 보험계약자에  |
# |              | 게 교부하는 증서                                                     |
# | 보험계약자   | 보험회사와 계약을 체결하고 보험료 납입의무를 지는 사람               |
# | 피보험자     | 보험사고 발생의 대상이 되는 사람                                     |
# | 보험수익자   | 보험사고 발생시 보험금 청구권을 갖는 사람                            |
# | 보험료       | 보험계약자가 보험계약에 의거하여 보험회사에게 지급하여야하는 요금    |
# | 보험목적     | 보험사고의 발생의 객체가 되는 경제상의 재화                          |
# | 보험가액     | 재산보험에 있어 피보험 이익을 금전으로 평가한 금액으로 보험의 목적   |
# |              | 에 발생할 수 있는 최대 손해액을 말합니다.(회사가 실제 지급하는 보험  |
# |              | 금은 보험가액을 초과할 수 없습니다)                                  |
# ...

# %% [markdown]
# ### Image

# %%
import pdfplumber
import io
from PIL import Image

def extract_images_from_pdf(file_name, output_folder):

    # PDF 파일 열기
    with pdfplumber.open(file_name) as pdf:
        image_index = 0  # 이미지 인덱스 초기화

        # 각 페이지에서 이미지 추출
        for page_num, page in enumerate(pdf.pages, start=1):
            # 페이지에서 이미지 추출
            images = page.images

            # 페이지에 이미지가 있다면
            for img_index, image in enumerate(images, start=1):
                # 이미지 정보 가져오기
                image_bytes = image['stream'].get_data()  # 이미지 바이트 데이터

                image_filename = f"{output_folder}/page_{page_num}_img_{img_index}.png"
                # 이미지 파일 저장
                with open(image_filename, "wb") as img_file:
                    img_file.write(image_bytes)

                print(f"Saved image {image_filename}")


                # 이미지 바이트를 이미지 객체로 변환할 경우 사용
                # image = Image.open(io.BytesIO(image_bytes))
                
                # # 이미지 저장
                # image.save(image_filename)
                # print(f"Image saved: {image_filename}")



# 사용 예시
output_folder = "plumber_images"  # 이미지가 저장될 폴더
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
extract_images_from_pdf(file_name, output_folder)
# Out:
# Saved image plumber_images/page_6_img_1.png
# Saved image plumber_images/page_6_img_2.png
# Saved image plumber_images/page_6_img_3.png
# Saved image plumber_images/page_6_img_4.png
# Saved image plumber_images/page_37_img_1.png
# Saved image plumber_images/page_37_img_2.png
# Saved image plumber_images/page_42_img_1.png
# Saved image plumber_images/page_42_img_2.png
# Saved image plumber_images/page_43_img_1.png
# Saved image plumber_images/page_43_img_2.png
# Saved image plumber_images/page_43_img_3.png

# %% [markdown]
# ### Image - Display

# %%
import pdfplumber
import io
from PIL import Image
from IPython.display import display

pdf = pdfplumber.open(file_name)
all_images = []
for page in pdf.pages:
    for image in page.images:
        all_images.append(image) 

for img in all_images:
    image_dict = img
    image_stream = image_dict['stream']
    image_data = image_stream.get_data()
    image_bytes = io.BytesIO(image_data)
    real_image = Image.open(image_bytes)

    display(real_image)

pdf.close()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=113x93>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=113x95>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=114x95>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=114x95>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=582x380>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=573x380>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=377x337>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=337x306>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x218>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=413x430>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x397>
